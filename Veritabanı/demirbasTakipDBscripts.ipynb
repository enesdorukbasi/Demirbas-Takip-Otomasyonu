-- %% [markdown]
-- # [demirbasTakipDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [demirbasTakipDB]    Script Date: 8.01.2021 14:41:22 ******/
CREATE DATABASE [demirbasTakipDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'demirbasTakipDB', FILENAME = N'C:\Users\Lenovo\demirbasTakipDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'demirbasTakipDB_log', FILENAME = N'C:\Users\Lenovo\demirbasTakipDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
ALTER DATABASE [demirbasTakipDB] SET COMPATIBILITY_LEVEL = 130
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [demirbasTakipDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [demirbasTakipDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [demirbasTakipDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [demirbasTakipDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [demirbasTakipDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET  ENABLE_BROKER 
GO
ALTER DATABASE [demirbasTakipDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [demirbasTakipDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [demirbasTakipDB] SET  MULTI_USER 
GO
ALTER DATABASE [demirbasTakipDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [demirbasTakipDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [demirbasTakipDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [demirbasTakipDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [demirbasTakipDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [demirbasTakipDB] SET QUERY_STORE = OFF
GO
USE [demirbasTakipDB]
GO
ALTER DATABASE SCOPED CONFIGURATION SET LEGACY_CARDINALITY_ESTIMATION = OFF;
GO
ALTER DATABASE SCOPED CONFIGURATION SET MAXDOP = 0;
GO
ALTER DATABASE SCOPED CONFIGURATION SET PARAMETER_SNIFFING = ON;
GO
ALTER DATABASE SCOPED CONFIGURATION SET QUERY_OPTIMIZER_HOTFIXES = OFF;
GO

-- %% [markdown]
-- # [dbo].[tbl_Kategoriler]

-- %%
USE [demirbasTakipDB]
GO

-- %%
/****** Object:  Table [dbo].[tbl_Kategoriler]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_Kategoriler](
	[kategori_id] [int] IDENTITY(1,1) NOT NULL,
	[kategori_ad] [nvarchar](30) NULL,
PRIMARY KEY CLUSTERED 
(
	[kategori_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_personel]

-- %%
/****** Object:  Table [dbo].[tbl_personel]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_personel](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ad] [nvarchar](20) NULL,
	[soyad] [nvarchar](30) NULL,
	[sicil] [nvarchar](10) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_urunler]

-- %%
/****** Object:  Table [dbo].[tbl_urunler]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_urunler](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ad] [nvarchar](30) NULL,
	[stokAdet] [int] NULL,
	[kategori_id] [int] NULL,
	[kategori_ad] [nvarchar](20) NULL,
	[zimmet] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_Yönetici]

-- %%
/****** Object:  Table [dbo].[tbl_Yönetici]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_Yönetici](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[AdSoyad] [nvarchar](50) NULL,
	[Unvan] [nvarchar](30) NULL,
	[Sifre] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_zimmet]

-- %%
/****** Object:  Table [dbo].[tbl_zimmet]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_zimmet](
	[zimmet_id] [int] IDENTITY(1,1) NOT NULL,
	[zimmet_ad] [nvarchar](30) NULL,
	[zimmet_tarih] [date] NULL,
	[kategori_id] [int] NULL,
	[kategori_ad] [nvarchar](30) NULL,
	[urunid] [int] NULL,
	[urunad] [nvarchar](30) NULL,
	[perid] [int] NULL,
	[perad] [nvarchar](100) NULL,
	[persoyad] [nvarchar](30) NULL,
PRIMARY KEY CLUSTERED 
(
	[zimmet_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_tbl_urunler_To_tbl_kategoriler]

-- %%
ALTER TABLE [dbo].[tbl_urunler]  WITH CHECK ADD  CONSTRAINT [FK_tbl_urunler_To_tbl_kategoriler] FOREIGN KEY([kategori_id])
REFERENCES [dbo].[tbl_Kategoriler] ([kategori_id])
GO
ALTER TABLE [dbo].[tbl_urunler] CHECK CONSTRAINT [FK_tbl_urunler_To_tbl_kategoriler]
GO

-- %% [markdown]
-- # [FK_tbl_zimmet_To_tbl_kategoriler]

-- %%
ALTER TABLE [dbo].[tbl_zimmet]  WITH CHECK ADD  CONSTRAINT [FK_tbl_zimmet_To_tbl_kategoriler] FOREIGN KEY([kategori_id])
REFERENCES [dbo].[tbl_Kategoriler] ([kategori_id])
GO
ALTER TABLE [dbo].[tbl_zimmet] CHECK CONSTRAINT [FK_tbl_zimmet_To_tbl_kategoriler]
GO

-- %% [markdown]
-- # [FK_tbl_zimmet_To_tbl_personel]

-- %%
ALTER TABLE [dbo].[tbl_zimmet]  WITH CHECK ADD  CONSTRAINT [FK_tbl_zimmet_To_tbl_personel] FOREIGN KEY([perid])
REFERENCES [dbo].[tbl_personel] ([Id])
GO
ALTER TABLE [dbo].[tbl_zimmet] CHECK CONSTRAINT [FK_tbl_zimmet_To_tbl_personel]
GO

-- %% [markdown]
-- # [FK_tbl_zimmet_To_tbl_urunler]

-- %%
ALTER TABLE [dbo].[tbl_zimmet]  WITH CHECK ADD  CONSTRAINT [FK_tbl_zimmet_To_tbl_urunler] FOREIGN KEY([urunid])
REFERENCES [dbo].[tbl_urunler] ([Id])
GO
ALTER TABLE [dbo].[tbl_zimmet] CHECK CONSTRAINT [FK_tbl_zimmet_To_tbl_urunler]
GO

-- %% [markdown]
-- # [dbo].[sp_kategori_ekle]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_kategori_ekle]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_kategori_ekle]
	@kategori_ad	nvarchar(30)
AS
	insert into tbl_kategoriler values(@kategori_ad) select @@IDENTITY
GO

-- %% [markdown]
-- # [dbo].[sp_kategori_guncelle]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_kategori_guncelle]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_kategori_guncelle]
	@kategori_id	int,
	@kategori_ad	nvarchar(30)
AS
	update tbl_kategoriler set kategori_ad=@kategori_ad where kategori_id=@kategori_id
GO

-- %% [markdown]
-- # [dbo].[sp_kategori_listele]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_kategori_listele]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_kategori_listele]
	
AS
	select k.kategori_ad,
			k.kategori_ad,
			u.Id,
			u.ad,
			u.stokAdet,
			u.zimmet,
			u.kategori_id
	from tbl_kategoriler k inner join tbl_urunler u on u.Id=u.kategori_id
GO

-- %% [markdown]
-- # [dbo].[sp_kategori_sil]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_kategori_sil]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_kategori_sil]
	@kategori_id	int
	
AS
	delete from tbl_kategoriler where kategori_id=@kategori_id
GO

-- %% [markdown]
-- # [dbo].[sp_per_giris]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_per_giris]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_per_giris]
	@ad		nvarchar(30),
	@sicil	nvarchar(10)
AS
	if(select count(*)from tbl_personel where ad=@ad and sicil=@sicil)>0
	select 1
	else
	select 0
GO

-- %% [markdown]
-- # [dbo].[sp_personel_ekle]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_personel_ekle]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_personel_ekle]
	@ad		nvarchar(20),
	@soyad	nvarchar(30),
	@sicil	nvarchar(10)
AS
	insert into tbl_personel values(@ad,@soyad,@sicil)
	select @@IDENTITY
GO

-- %% [markdown]
-- # [dbo].[sp_personel_guncelle]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_personel_guncelle]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_personel_guncelle]
	@id		int,
	@ad		nvarchar(20),
	@soyad	nvarchar(30),
	@sicil	nvarchar(10)
AS
	update tbl_personel set ad=@ad,soyad=@soyad,sicil=@sicil where id=@id
GO

-- %% [markdown]
-- # [dbo].[sp_personel_listele]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_personel_listele]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_personel_listele]
as
	select * from tbl_personel
GO

-- %% [markdown]
-- # [dbo].[sp_personel_sil]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_personel_sil]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_personel_sil]
	@id		int
AS
	delete from tbl_personel where Id=@id
GO

-- %% [markdown]
-- # [dbo].[sp_urun_ekle]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_urun_ekle]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_urun_ekle]
	@ad		nvarchar(30),
	@stokAdet	int,
	@kategori_id int,
	@kategori_ad	nvarchar(30),
	@zimmet		nvarchar(50)
AS
	insert into tbl_urunler values(@ad,@stokAdet,@kategori_id,@kategori_ad,@zimmet)
	select @@IDENTITY
GO

-- %% [markdown]
-- # [dbo].[sp_urun_guncelle]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_urun_guncelle]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_urun_guncelle]
	@id		int,
	@ad		nvarchar(30),
	@stokAdet	int,
	@kategori_id int,
	@kategori_ad	nvarchar(30),
	@zimmet		nvarchar(30)
AS
	update tbl_urunler set ad=@ad,stokAdet=@stokAdet,kategori_id=@kategori_id,kategori_ad=@kategori_ad,zimmet=@zimmet
	where Id=@id
GO

-- %% [markdown]
-- # [dbo].[sp_urun_listele]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_urun_listele]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_urun_listele]
AS
	select * from tbl_urunler
GO

-- %% [markdown]
-- # [dbo].[sp_urun_sil]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_urun_sil]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_urun_sil]
	@id		int
AS
	delete from tbl_urunler where Id= @id
GO

-- %% [markdown]
-- # [dbo].[sp_yönetici_ekle]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_yönetici_ekle]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_yönetici_ekle]
	@AdSoyad	nvarchar(50),
	@Unvan	nvarchar(30),
	@Sifre int
AS
	insert into tbl_Yönetici values (@AdSoyad,@Unvan,@Sifre) select @@IDENTITY
GO

-- %% [markdown]
-- # [dbo].[sp_yonetici_giris]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_yonetici_giris]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_yonetici_giris]
	@AdSoyad	nvarchar(50),
	@Sifre		int
AS
	  if(select count(*)from tbl_Yönetici where AdSoyad=@AdSoyad and Sifre=@Sifre)>0
	select 1
	else
	select 0
GO

-- %% [markdown]
-- # [dbo].[sp_yonetici_guncelle]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_yonetici_guncelle]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_yonetici_guncelle]
	@id			int,
	@AdSoyad	nvarchar(50),
	@Unvan		nvarchar(30),
	@Sifre		int
AS
	update tbl_Yönetici set AdSoyad=@AdSoyad,Unvan=@Unvan,Sifre=@Sifre where Id=@id
GO

-- %% [markdown]
-- # [dbo].[sp_yonetici_listele]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_yonetici_listele]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_yonetici_listele]
AS
	select * from tbl_Yönetici
GO

-- %% [markdown]
-- # [dbo].[sp_yonetici_sil]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_yonetici_sil]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_yonetici_sil]
	@id			int
	
AS
	delete from tbl_Yönetici  where Id=@id
GO

-- %% [markdown]
-- # [dbo].[sp_zimmet_guncelle]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_zimmet_guncelle]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_zimmet_guncelle]
	@zimmet_id		int,
	@zimmet_ad		nvarchar(30),
	@zimmet_tarih	date,
	@kategori_ad	nvarchar(30),
	@urunad			nvarchar(30),
	@perad			nvarchar(20),
	@perSoyad		nvarchar(30)
AS
	update tbl_zimmet set zimmet_ad=@zimmet_ad,zimmet_tarih=@zimmet_tarih,kategori_ad=@kategori_ad,urunad=@urunad,perad=@perad,persoyad=@perSoyad where zimmet_id=@zimmet_id
GO

-- %% [markdown]
-- # [dbo].[sp_zimmet_listele]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_zimmet_listele]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_zimmet_listele]
	
AS
	select * from tbl_zimmet
GO

-- %% [markdown]
-- # [dbo].[sp_zimmet_sil]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_zimmet_sil]    Script Date: 8.01.2021 14:41:23 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_zimmet_sil]
	@zimmet_id		int
AS
	delete from tbl_zimmet where zimmet_id=@zimmet_id
GO

-- %% [markdown]
-- # [demirbasTakipDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [demirbasTakipDB] SET  READ_WRITE 
GO
